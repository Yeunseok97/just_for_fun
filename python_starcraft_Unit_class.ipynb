# %% [markdown]
# #Unit information of starcraft 1

# %%
class Unit():
  
  def __init__(self, tribe, name, mineral_require, gas_require, production_time, production_building, unit_type,
               unit_size, unit_width, unit_height, transport_size, HP, MP, passive_armor, upgrade_armor_increase,
               moving_type, moving_pace, sight_range, passive_damage, damage_type, attack_range, attack_speed,
               passive_attack_effect, upgrade_damage_increase, passive_skill, characteristic_upgrade1, characteristic_upgrade2,
               characteristic_upgrade3, characteristic_upgrade4):
    
    self.tribe = tribe,
    self.name = name,
    self.mineral_require = mineral_require
    self.gas_require = gas_require
    self.production_time = production_time
    self.production_building = production_building
    self.unit_type = unit_type
    self.unit_size = unit_size
    self.unit_width = unit_width
    self.unit_height = unit_height
    self.transport_size = transport_size
    self.HP = HP
    self.MP = MP
    self.passive_armor = passive_armor
    self.upgrade_armor_increase = upgrade_armor_increase
    self.moving_type = moving_type
    self.moving_pace = moving_pace
    self.sight_range = sight_range
    self.passive_damage = passive_damage
    self.damage_type = damage_type
    self.attack_range = attack_range
    self.attack_speed = attack_speed
    self.passive_attack_effect = passive_attack_effect
    self.upgrade_damage_increase = upgrade_damage_increase
    self.passive_skill = passive_skill
    self.characteristic_upgrade1 = characteristic_upgrade1
    self.characteristic_upgrade2 = characteristic_upgrade2
    self.characteristic_upgrade3 = characteristic_upgrade3
    self.characteristic_upgrade4 = characteristic_upgrade4
  
  def who(self):
    print("종족 : {}, 이름 : {}, 미네랄요구량 : {}, 가스요구량 : {}, 생산시간 : {} 생산건물 : {}".format(self.tribe, self.name, self.mineral_require, self.gas_require, self.production_time, self.production_building))
    print("유닛 타입 : {}, 유닛 사이즈 : {}, 유닛 너비 : {}, 유닛 높이 : {} 수송 칸 : {}".format(self.unit_type, self.unit_size, self.unit_width, self.unit_height, self.transport_size))
    print("HP : {} MP : {} 기본 아머 : {} 업그레이드 아머 증가량 : {} 이동 타입 : {} 이동 속도 : {} ".format(self.HP, self.MP, self.passive_armor, self.upgrade_armor_increase,self.moving_type, self.moving_pace))
    print("시야 범위 : {} 기본 공격력 : {} 공격 타입 : {} 공격 범위 : {} 공격 속도 : {} 기본 공격 효과 : {}".format(self.sight_range, self.passive_damage, self.damage_type, self.attack_range, self.attack_speed, self.passive_attack_effect))
    print("업그레이드 공격 증가량 : {} 특성 업그레이드1 : {} 특성 업그레이드2 : {} 특성 업그레이드3 : {} 특성 업그레이드4 : {}".format(self.upgrade_damage_increase,self.characteristic_upgrade1,self.characteristic_upgrade2,self.characteristic_upgrade3,self.characteristic_upgrade4))
  

  def set_Info(self, tribe, name, mineral_require, gas_require, production_time, production_building, unit_type,
               unit_size, unit_width, unit_height, transport_size, HP, MP, passive_armor, upgrade_armor_increase,
               moving_type, moving_pace, sight_range, passive_damage, damage_type, attack_range, attack_speed,
               passive_attack_effect, upgrade_damage_increase, passive_skill, characteristic_upgrade1, characteristic_upgrade2,
               characteristic_upgrade3, characteristic_upgrade4):
    
    self.tribe = tribe,
    self.name = name,
    self.mineral_require = mineral_require
    self.gas_require = gas_require
    self.production_time = production_time
    self.production_building = production_building
    self.unit_type = unit_type
    self.unit_size = unit_size
    self.unit_width = unit_width
    self.unit_height = unit_height
    self.transport_size = transport_size
    self.HP = HP
    self.MP = MP
    self.passive_armor = passive_armor
    self.upgrade_armor_increase = upgrade_armor_increase
    self.moving_type = moving_type
    self.moving_pace = moving_pace
    self.sight_range = sight_range
    self.passive_damage = passive_damage
    self.damage_type = damage_type
    self.attack_range = attack_range
    self.attack_speed = attack_speed
    self.passive_attack_effect = passive_attack_effect
    self.upgrade_damage_increase = upgrade_damage_increase
    self.passive_skill = passive_skill
    self.characteristic_upgrade1 = characteristic_upgrade1
    self.characteristic_upgrade2 = characteristic_upgrade2
    self.characteristic_upgrade3 = characteristic_upgrade3
    self.characteristic_upgrade4 = characteristic_upgrade4

medic = Unit("Terran", "medic",50,25,30, "barracks", "bionics", "small",)
  

#  require building, Max_MP,  MP -> Passive_MP, unit_class will be added
# Out:
#   File "<ipython-input-1-21c01f3e7010>", line 4
#     self.tribe = tribe,
#         ^
# SyntaxError: invalid syntax
